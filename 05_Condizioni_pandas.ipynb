# %% [markdown]
# # **Montare il file sul google drive** ☝

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Numpy & Pandas/Panda/bestsellers.csv')

# %% [markdown]
# ### Importare libreria

# %%
import pandas as pd

# %% [markdown]
# ### Caricare il DataFrame

# %%
df_books = pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv',sep=',',header=0)
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# # **Filtra per condizioni**

# %%
mayor_a_2016 = df_books['Year'] > 2016
mayor_a_2016.head(10)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# 9    False
# Name: Year, dtype: bool

# %%
top_reviews = df_books['Reviews'] > 15000
top_reviews
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# Name: Reviews, Length: 550, dtype: bool

# %%
df_books[df_books['Year'] > 2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
df_books[mayor_a_2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
genre_fiction = df_books['Genre'] == 'Fiction'
genre_fiction
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 545     True
# 546    False
# 547    False
# 548    False
# 549    False
# Name: Genre, Length: 550, dtype: bool

# %%
df_books[genre_fiction & mayor_a_2016 & top_reviews].head(15)
# Out:
#                                        Name             Author  User Rating  \
# 3                    1984 (Signet Classics)      George Orwell          4.7
# 7            A Gentleman in Moscow: A Novel        Amor Towles          4.7
# 10                A Man Called Ove: A Novel    Fredrik Backman          4.6
# 178            If Animals Kissed Good Night  Ann Whitford Paul          4.8
# 179            If Animals Kissed Good Night  Ann Whitford Paul          4.8
# 220                 Little Fires Everywhere         Celeste Ng          4.5
# 250               Oh, the Places You'll Go!          Dr. Seuss          4.9
# 251               Oh, the Places You'll Go!          Dr. Seuss          4.9
# 252               Oh, the Places You'll Go!          Dr. Seuss          4.9
# 258        Origin: A Novel (Robert Langdon)          Dan Brown          4.3
# 265  Player's Handbook (Dungeons & Dragons)   Wizards RPG Team          4.8
# ...

# %% [markdown]
# # **Negare la Condizione**

# %%
df_books[~mayor_a_2016]
# Out:
#                                                   Name  ...        Genre
# 0                        10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                    11/22/63: A Novel  ...      Fiction
# 5        A Dance with Dragons (A Song of Ice and Fire)  ...      Fiction
# 6    A Game of Thrones / A Clash of Kings / A Storm...  ...      Fiction
# 9                            A Man Called Ove: A Novel  ...      Fiction
# ..                                                 ...  ...          ...
# 540                                             Wonder  ...      Fiction
# 541                                             Wonder  ...      Fiction
# 542                                             Wonder  ...      Fiction
# 543                                             Wonder  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [400 rows x 7 columns]

# %% [markdown]
# # **Filtrare una colonna di testo**

# %%
df_books[df_books['Author'].str.contains('Palacio')]
# Out:
#        Name         Author  User Rating  Reviews  Price  Year    Genre
# 540  Wonder  R. J. Palacio          4.8    21625      9  2013  Fiction
# 541  Wonder  R. J. Palacio          4.8    21625      9  2014  Fiction
# 542  Wonder  R. J. Palacio          4.8    21625      9  2015  Fiction
# 543  Wonder  R. J. Palacio          4.8    21625      9  2016  Fiction
# 544  Wonder  R. J. Palacio          4.8    21625      9  2017  Fiction

# %% [markdown]
# Se vogliamo porre più condizioni senza esprimerle prima, dobbiamo metterle separatamente tra parentesi:

# %%
df_books[(df_books['Year'] > 2016) & (df_books['Price'] == 9)]
# Out:
#                                                   Name               Author  \
# 26                  Astrophysics for People in a Hurry  Neil deGrasse Tyson
# 257  Option B: Facing Adversity, Building Resilienc...      Sheryl Sandberg
# 467                            The Sun and Her Flowers            Rupi Kaur
# 496                               Thirteen Reasons Why            Jay Asher
# 544                                             Wonder        R. J. Palacio
#
#      User Rating  Reviews  Price  Year        Genre
# 26           4.7     9374      9  2017  Non Fiction
# 257          4.5     1831      9  2017  Non Fiction
# 467          4.7     5487      9  2017  Non Fiction
# 496          4.5     7932      9  2017      Fiction
# 544          4.8    21625      9  2017      Fiction
